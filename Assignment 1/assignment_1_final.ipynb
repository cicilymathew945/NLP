# %% [markdown]
# ## __Assignment 1__
#
# ### HW Group 9
# ### Authors: Bradley Stoller, Bruna Medeiros, Casey Maldonado, Cicily Matthew, John Melel
# ### Date: 03/31/2025

# %%
# Importing libraries
import pandas as pd
import re
import matplotlib.pyplot as plt
import nltk
from nltk import pos_tag
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet
from collections import Counter
from matplotlib.ticker import FuncFormatter

# %%
# Load the dataset
url = "https://storage.googleapis.com/adsp-nlp-open/data/Food_Inspections_20250325.csv"
df = pd.read_csv(url)

# %% [markdown]
# ### 1. Select only the records corresponding to failed inspections (see the "results" column).

# %%
# Here we filter for failed inspections only
df_failed = df[df['Results'].str.lower() == 'fail'].copy()
df_failed.head()
# Out:
#    Inspection ID                   DBA Name                   AKA Name  \
# 0        1068208     CHINA COURT RESTAURANT     CHINA COURT RESTAURANT
# 5        1072529  GRESHAM ELEMENTARY SCHOOL  GRESHAM ELEMENTARY SCHOOL
# 6        1084236          THE JIBARITO STOP          THE JIBARITO STOP
# 7        1084239        MANJARES AL EXPRESS        MANJARES AL EXPRESS
# 8        1084242                  CHISCREAM                  CHISCREAM
#
#    License #          Facility Type           Risk                  Address  \
# 0  2141795.0             Restaurant  Risk 1 (High)     1146 N MILWAUKEE AVE
# 5    23451.0                 School  Risk 1 (High)      8524 S Green (832W)
# 6  2156722.0  Mobile Food Dispenser   Risk 3 (Low)    2007-2009 S DAMEN AVE
# 7  2021538.0             Restaurant  Risk 1 (High)  2226-2230 S ASHLAND AVE
# 8  2152278.0  Mobile Food Dispenser   Risk 3 (Low)         324 N LEAVITT ST
#
#       City State      Zip Inspection Date        Inspection Type Results  \
# 0  CHICAGO    IL  60642.0      03/14/2012  License Re-Inspection    Fail
# 5  CHICAGO    IL  60620.0      09/05/2013                Canvass    Fail
# 6  CHICAGO    IL  60608.0      05/25/2012                License    Fail
# 7  CHICAGO    IL  60608.0      05/29/2012              Complaint    Fail
# 8  CHICAGO    IL  60612.0      06/04/2012                License    Fail
#
#                                           Violations   Latitude  Longitude  \
# 0  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.902462 -87.665306
# 5  12. HAND WASHING FACILITIES: WITH SOAP AND SAN...  41.738913 -87.645062
# 6  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.854695 -87.675765
# 7  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.851398 -87.666166
# 8  1. SOURCE SOUND CONDITION, NO SPOILAGE, FOODS ...  41.887434 -87.681849
#
#                                    Location
# 0  (41.902462266949634, -87.66530609467256)
# 5    (41.73891334027122, -87.6450616939937)
# 6  (41.854694701707345, -87.67576513516751)
# 7  (41.851397799712196, -87.66616621226514)
# 8   (41.88743405025222, -87.68184949426895)

# %% [markdown]
# ### 2. Use regular expressions to extract the regulation description and inspector comments from the "violations" columns.

# %%
def extract_violations(text):
    """
    Extracts violations from a given text string.

    This function parses a string containing violation details, splits it into individual violations,
    and extracts the code, description, and optional comments for each violation.

    Parameters:
    text (str): A string containing violation details, where each violation is separated by '|'.
                Each violation is expected to follow the format:
                '<code>. <description> - Comments: <comment>'.

    Returns:
    list: A list of tuples, where each tuple contains:
          - code (str): The violation code.
          - desc (str): The violation description.
          - comment (str): The optional comment associated with the violation. If no comment is present, an empty string is returned.
    """
    if pd.isnull(text):
        return []
    
    violations = text.split('|')
    result = []
    for v in violations:
        v = v.strip()
        match = re.match(r'^\s*(\d+)\.\s*(.*?)(?:\s*-\s*Comments:\s*(.*))?$', v, re.IGNORECASE)
        if match:
            code = match.group(1).strip()
            desc = match.group(2).strip()
            comment = match.group(3).strip() if match.group(3) else ''
            result.append((code, desc, comment))
    return result

# %%
# Parsing the violations
df_failed["Parsed_Violation"] = df_failed["Violations"].apply(extract_violations)
df_failed = df_failed.explode("Parsed_Violation")

# %%
df_failed[['DBA Name', 'Parsed_Violation']].head(10)
# Out:
#                     DBA Name  \
# 0     CHINA COURT RESTAURANT
# 0     CHINA COURT RESTAURANT
# 0     CHINA COURT RESTAURANT
# 5  GRESHAM ELEMENTARY SCHOOL
# 5  GRESHAM ELEMENTARY SCHOOL
# 5  GRESHAM ELEMENTARY SCHOOL
# 6          THE JIBARITO STOP
# 6          THE JIBARITO STOP
# 6          THE JIBARITO STOP
# 7        MANJARES AL EXPRESS
#
#                                     Parsed_Violation
# 0  (18, NO EVIDENCE OF RODENT OR INSECT OUTER OPE...
# 0  (32, FOOD AND NON-FOOD CONTACT SURFACES PROPER...
# 0  (41, PREMISES MAINTAINED FREE OF LITTER, UNNEC...
# 5  (12, HAND WASHING FACILITIES: WITH SOAP AND SA...
# 5  (18, NO EVIDENCE OF RODENT OR INSECT OUTER OPE...
# 5  (34, FLOORS: CONSTRUCTED PER CODE, CLEANED, GO...
# 6  (18, NO EVIDENCE OF RODENT OR INSECT OUTER OPE...
# 6  (32, FOOD AND NON-FOOD CONTACT SURFACES PROPER...
# 6  (34, FLOORS: CONSTRUCTED PER CODE, CLEANED, GO...
# 7  (2, FACILITIES TO MAINTAIN PROPER TEMPERATURE,...

# %%
# Extracting the code, description, and comment into separate columns
df_failed[['Code_Number', 'Violation_Description', 'Violation_Comment']] = pd.DataFrame(
    df_failed['Parsed_Violation'].tolist(), index=df_failed.index
)

# %%
df_failed[['DBA Name', 'Parsed_Violation', 'Code_Number', 'Violation_Description', 'Violation_Comment']].head(3)
# Out:
#                  DBA Name                                   Parsed_Violation  \
# 0  CHINA COURT RESTAURANT  (18, NO EVIDENCE OF RODENT OR INSECT OUTER OPE...
# 0  CHINA COURT RESTAURANT  (32, FOOD AND NON-FOOD CONTACT SURFACES PROPER...
# 0  CHINA COURT RESTAURANT  (41, PREMISES MAINTAINED FREE OF LITTER, UNNEC...
#
#   Code_Number                              Violation_Description  \
# 0          18  NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS...
# 0          32  FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DE...
# 0          41  PREMISES MAINTAINED FREE OF LITTER, UNNECESSAR...
#
#                                    Violation_Comment
# 0  FOUND NO PEST CONTROL LOG BOOK ON PREMISES,FRO...
# 0  SPLASHGUARD AT FRONT EXPOSED HANDSINK IS MISSI...
# 0  DETAIL CLEAN,ORGANIZE REAR STORAGE AREAS AND R...

# %% [markdown]
# ### 3. Count how many times each regulation description occurred in the table and visualize the top 10 most frequent regulation descriptions.

# %%
# Visualizing the top 10 violation descriptions
top_violations = df_failed['Violation_Description'].value_counts().iloc[:10].sort_values()

top_violations.plot(kind= 'barh')
plt.xlabel('Count of Violations', fontsize= 12, fontweight= 'bold')
plt.ylabel('Violation Description', fontsize= 12, fontweight= 'bold')
plt.title('Top 10 Violation Descriptions', fontsize= 18, fontweight= 'bold')
plt.show()

# %% [markdown]
# ### 4. Tokenize the comments and provide a count of the top 10:
#    1. Raw tokens
#    2. Preprocessed tokens
#    3. Preprocessed tokens + Porter stemmer
#    4. Preprocessed tokens + Lancaster stemmer
#    5. Preprocessed tokens + lemmatization

# %%
porter = nltk.PorterStemmer()
lancaster = nltk.LancasterStemmer()
lemmatizer = nltk.WordNetLemmatizer()

# %%
def get_wordnet_pos(treebank_tag, skip_value = "n"):
    """
    Converts treebank part-of-speech tags to WordNet part-of-speech tags.

    This function maps the treebank POS tags (used in NLTK's pos_tag function) 
    to the corresponding WordNet POS tags, which are required for lemmatization.

    Parameters:
    treebank_tag (str): The POS tag from the treebank (e.g., 'NN', 'VB', 'JJ', etc.).
    skip_value (str): The default WordNet POS tag to return if no match is found. Default is 'n' (noun).

    Returns:
    str: The corresponding WordNet POS tag (e.g., 'a' for adjective, 'v' for verb, 'n' for noun, 'r' for adverb).
    """
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return skip_value

# %%
# cleaning
comments = df_failed["Violation_Comment"].dropna()
comments = comments[comments.apply(lambda x: isinstance(x, str))]
text = ' '.join(comments)

# %%
raw_tokens = word_tokenize(text)

# %%
# Filtering out non-alphabetic tokens and stop words
stop_words = set(stopwords.words('english'))
preprocessed = [
    token.lower()
    for token in raw_tokens
    if token.isalpha() and token.lower() not in stop_words
]

# %%
porter_stemmed = [porter.stem(token) for token in preprocessed]

# %%
lancaster_stemmed = [lancaster.stem(token) for token in preprocessed]

# %%
tagged = pos_tag(preprocessed)
lemmatized = [lemmatizer.lemmatize(token, get_wordnet_pos(pos)) for token, pos in tagged]

# %%
tokenized_component_names = [
    "Raw Tokens",
    "Preprocessed",
    "Porter Stemmed",
    "Lancaster Stemmed",
    "Lemmatized"
]

tokenized_components = [
    raw_tokens,
    preprocessed,
    porter_stemmed,
    lancaster_stemmed,
    lemmatized
]

# %%
# Create a DataFrame to rank and print the top 10 tokens for each method
ranked_columns = {}

for name, tokens in zip(tokenized_component_names, tokenized_components):
    top_tokens = Counter(tokens).most_common(10)
    ranked_columns[name] = [f"{token}" for token, count in top_tokens]

ranked_df = pd.DataFrame(ranked_columns)
ranked_df.index += 1
ranked_df.index.name = "Rank"

ranked_df
# Out:
#       Raw Tokens Preprocessed Porter Stemmed Lancaster Stemmed Lemmatized
# Rank
# 1              .         must           food              food       food
# 2            AND   instructed           must              must       must
# 3              ,         food           area               cle       area
# 4            THE     observed       instruct          instruct      clean
# 5             IN        clean          clean            observ   instruct
# 6             TO         area         observ               are   maintain
# 7             OF     maintain       maintain          maintain       sink
# 8           MUST         prep           sink              prep      floor
# 9             ON         sink          floor              sink    observe
# 10    INSTRUCTED      provide         provid              stor    provide

# %%
# Visualizing the top 10 tokens for each method
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(25, 5), sharey=True)
fig.suptitle("Top 10 Tokens by Text Preprocessing Type", fontsize=16)

formatter = FuncFormatter(lambda x, _: f'{int(x / 1000)}K')  # Format x-axis in thousands

for ax, name, tokens in zip(axes, tokenized_component_names, tokenized_components):
    top = Counter(tokens).most_common(10)
    labels, counts = zip(*top)
    ax.barh(labels, counts)
    ax.set_title(name)
    ax.invert_yaxis()
    ax.xaxis.set_major_formatter(formatter)  # Apply formatter to x-axis

plt.tight_layout(rect=[0, 0, 1, 0.95])  # Leave space for suptitle
plt.show()

# %% [markdown]
# ### 5. Briefly describe the differences in various tokens from (4).

# %% [markdown]
# From the table and chart above, we see that the main difference between the raw tokens and the other tokens (preprocessed, Porter stemmed, Lancaster stemmed, and lemmatized) is the captilization, since the text from the original dataset was all uppercase. Additionally, we further see that many of the top tokens in the raw tokens are words like "AND", "THE, and "TO", which are common english stop-words. Thus, it makes sense that these are not included in the preprocessed tokens.
#
# After preprocessing, we see that meaningful, non stop-words exist such as "must", "food", and "instructed" appear. When applying the Porter and the Lancaster stemming we see that many of the words are simplified, for example "clean" becoming "cle" and "provide" becoming "provid". Lancaster stemmer shows more aggressive stemming, with even basic words like "clean" and "area" being stemmed.
# Howvever, with the lemmatized words, we see that the words are still readable, but just in their base forms, such as "must", "instruct" and "provide".
#
# Ultimately, the progression of how these words changed throughout the tokenization process highlights the importance of preprocessing, and shows how important it is to extract the most notable comment insights from the restaurant violations.
